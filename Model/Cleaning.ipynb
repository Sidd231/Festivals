# %% [markdown]
# # Importing

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Dataset

# %%
# data of sales
df = pd.read_csv("..\\DataSet\\train.csv")
# data of festivals
fd = pd.read_excel("..\\DataSet\\festivals_base.xlsx")

# %% [markdown]
# # Data cleaning
